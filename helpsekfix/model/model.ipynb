# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ollama import ChatOllama
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

# %%
import json
from langchain.schema import Document

documents = []

# ----------------------------
# 1. Proses file formasi CPNS
# ----------------------------
cpns_file = '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json'

with open(cpns_file, 'r', encoding='utf-8') as f:
    raw_cpns = json.load(f)

# Pastikan berupa list
if isinstance(raw_cpns, dict):
    raw_cpns = [raw_cpns]
elif not isinstance(raw_cpns, list):
    raise ValueError("File formasi harus berupa object atau array of object.")

# ----------------------------
# 2. Konversi ke Document
# ----------------------------
for idx, item in enumerate(raw_cpns):
    # Gabungkan semua field penting ke dalam teks (content)
    # Format teks dibuat agar mudah dipahami oleh model RAG
    text_parts = [
        f"Jabatan: {item.get('jabatan', 'Tidak disebutkan')}",
        f"Instansi: {item.get('instansi', 'Tidak disebutkan')}",
        f"Unit Kerja: {item.get('unit_kerja', 'Tidak disebutkan')}",
        f"Penempatan: {item.get('penempatan', 'Tidak disebutkan')}",
    ]
    
    if 'catatan_penempatan' in item:
        text_parts.append(f"Catatan Penempatan: {item['catatan_penempatan']}")
    
    text_parts.extend([
        f"Jenis Formasi: {item.get('jenis_formasi', 'Tidak disebutkan')}",
        f"Khusus Disabilitas: {'Ya' if item.get('khusus_disabilitas', False) else 'Tidak'}",
        f"Penghasilan (juta): {item['penghasilan']['min']} - {item['penghasilan']['max']}",
        f"Jumlah Kebutuhan: {item.get('jumlah_kebutuhan', 0)}",
    ])

    # Format kualifikasi pendidikan (list)
    pendidikan = item.get('kualifikasi_pendidikan', [])
    if isinstance(pendidikan, str):
        pendidikan = [pendidikan]
    pendidikan_str = "; ".join(pendidikan)
    text_parts.append(f"Kualifikasi Pendidikan: {pendidikan_str}")

    if 'website_instansi' in item:
        text_parts.append(f"Website Instansi: {item['website_instansi']}")

    # Gabung jadi satu teks
    page_content = "\n".join(text_parts)

    # Metadata untuk filtering cepat di RAG
    metadata = {
        "jabatan": item.get("jabatan"),
        "instansi": item.get("instansi"),
        "jenis_formasi": item.get("jenis_formasi"),
        "khusus_disabilitas": item.get("khusus_disabilitas", False),
        "penempatan": item.get("penempatan"),
        "min_gaji": item["penghasilan"]["min"],
        "max_gaji": item["penghasilan"]["max"],
        "jumlah_kebutuhan": item.get("jumlah_kebutuhan", 0),
        "sumber_file": cpns_file,
        "index": idx
    }

    # Buat Document
    doc = Document(page_content=page_content, metadata=metadata)
    documents.append(doc)

# %%
documents
# Out:
# [Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Lulusan Terbaik', 'khusus_disabilitas': True, 'penempatan': 'Jakarta', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 75, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 0}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Jakarta\nJenis Formasi: CPNS Lulusan Terbaik\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 75\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Diaspora', 'khusus_disabilitas': True, 'penempatan': 'Jakarta', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 125, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 1}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Jakarta\nJenis Formasi: CPNS Diaspora\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 125\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Penyandang Disabilitas', 'khusus_disabilitas': True, 'penempatan': 'Jakarta', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 10, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 2}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Jakarta\nJenis Formasi: CPNS Penyandang Disabilitas\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 10\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Putra/putri Papua Dan Papua Barat', 'khusus_disabilitas': True, 'penempatan': 'Jakarta', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 2, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 3}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Jakarta\nJenis Formasi: CPNS Putra/putri Papua Dan Papua Barat\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 2\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Putra/putri Kalimantan', 'khusus_disabilitas': True, 'penempatan': 'Jakarta', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 25, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 4}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Jakarta\nJenis Formasi: CPNS Putra/putri Kalimantan\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 25\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENELITI AHLI MUDA', 'instansi': 'Badan Riset dan Inovasi Nasional', 'jenis_formasi': 'CPNS Umum', 'khusus_disabilitas': True, 'penempatan': 'Sumatra Utara: Nias Barat, Nias, Nias Utara, Nias Selatan.', 'min_gaji': 7, 'max_gaji': 11, 'jumlah_kebutuhan': 263, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 5}, page_content='Jabatan: PENELITI AHLI MUDA\nInstansi: Badan Riset dan Inovasi Nasional\nUnit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA\nPenempatan: Sumatra Utara: Nias Barat, Nias, Nias Utara, Nias Selatan.\nJenis Formasi: CPNS Umum\nKhusus Disabilitas: Ya\nPenghasilan (juta): 7 - 11\nJumlah Kebutuhan: 263\nKualifikasi Pendidikan: S3 semua jurusan'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Sumatra Barat: Kepulauan Mentawai.', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 65, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 6}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Sekretariat Jenderal | Biro Umum dan Layanan Pengadaan\nPenempatan: Sumatra Barat: Kepulauan Mentawai.\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 65\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Nusa Tenggara Barat: Lombok Utara', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 30, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 7}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Badan Pengembangan dan Informasi Desa, Daerah Tertinggal, dan Transmigrasi | Pusat Data dan Informasi Pembangunan Desa, Daerah Tertinggal, dan Transmigrasi\nPenempatan: Nusa Tenggara Barat: Lombok Utara\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 30\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Sulawesi Tengah: Donggala, Tojo Una-Una, Sigi.', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 24, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 8}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Badan Pengembangan dan Informasi Desa, Daerah Tertinggal, dan Transmigrasi | Sekretariat Badan Pengembangan dan Informasi Desa, Daerah Tertinggal, dan Transmigrasi\nPenempatan: Sulawesi Tengah: Donggala, Tojo Una-Una, Sigi.\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 24\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Papua Barat: Teluk Wondama, Pegunungan Arfak, Manokwari Selatan', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 19, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 9}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Direktorat Jenderal Pembangunan dan Pengembangan Kawasan Transmigrasi | Direktorat Perencanaan Perwujudan Kawasan Transmigrasi\nPenempatan: Papua Barat: Teluk Wondama, Pegunungan Arfak, Manokwari Selatan\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 19\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Sulawesi Tenggara: Konawe Kepulauan.', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 18, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 10}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Sekretariat Jenderal | Biro Keuangan dan Barang Milik Negara\nPenempatan: Sulawesi Tenggara: Konawe Kepulauan.\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 18\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Papua: Nabire, Kepulauan Yapen, Supiori, Mamberamo Raya, Mappi, Boven Digoel, Asmat, Keerom, Pegunungan Bintang, Yahukimo, Dogiyai, Puncak Jaya, Lanny Jaya, Nduga, Puncak, Tolikara, Intan Jaya, Paniai.', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 17, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 11}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Badan Pengembangan Sumber Daya Manusia dan Pemberdayaan Masyarakat Desa, Daerah Tertinggal, dan Transmigrasi | Pusat Pelatihan Pegawai Aparatur Sipil Negara Kementerian\nPenempatan: Papua: Nabire, Kepulauan Yapen, Supiori, Mamberamo Raya, Mappi, Boven Digoel, Asmat, Keerom, Pegunungan Bintang, Yahukimo, Dogiyai, Puncak Jaya, Lanny Jaya, Nduga, Puncak, Tolikara, Intan Jaya, Paniai.\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 17\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Sulawesi Utara: Kepulauan Siau Tagulandang Biaro (Sitaro), Kepulauan Talaud', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 15, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 12}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Badan Pengembangan dan Informasi Desa, Daerah Tertinggal, dan Transmigrasi | Pusat Pengembangan Daya Saing Desa, Daerah Tertinggal, dan Transmigrasi\nPenempatan: Sulawesi Utara: Kepulauan Siau Tagulandang Biaro (Sitaro), Kepulauan Talaud\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 15\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Sulawesi Barat: Mamasa', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 7, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 13}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Direktorat Jenderal Pengembangan Ekonomi dan Investasi Desa, Daerah Tertinggal, dan Transmigrasi | Direktorat Promosi dan Pemasaran Produk Unggulan Desa, Daerah Tertinggal, dan Transmigrasi\nPenempatan: Sulawesi Barat: Mamasa\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 7\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Bengkulu', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 3, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 14}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Badan Pengembangan Sumber Daya Manusia dan Pemberdayaan Masyarakat Desa, Daerah Tertinggal, dan Transmigrasi | Balai Pelatihan dan Pemberdayaan Masyarakat Desa, Daerah Tertinggal, dan Transmigrasi Bengkulu\nPenempatan: Bengkulu\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 3\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'PENATA LAYANAN OPERASIONAL', 'instansi': 'Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi', 'jenis_formasi': 'PPPK Teknis Khusus', 'khusus_disabilitas': False, 'penempatan': 'Lampung: Pesisir Barat', 'min_gaji': 5.5, 'max_gaji': 6.5, 'jumlah_kebutuhan': 1, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 15}, page_content='Jabatan: PENATA LAYANAN OPERASIONAL\nInstansi: Kementerian Desa, Pembangunan Daerah Tertinggal dan Transmigrasi\nUnit Kerja: KEMENTERIAN DESA, PEMBANGUNAN DAERAH TERTINGGAL, DAN TRANSMIGRASI | Inspektorat Jenderal | Inspektorat II\nPenempatan: Lampung: Pesisir Barat\nJenis Formasi: PPPK Teknis Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 5.5 - 6.5\nJumlah Kebutuhan: 1\nKualifikasi Pendidikan: S1 semua jurusan\nWebsite Instansi: https://kemendesa.go.id/'),
#  Document(metadata={'jabatan': 'ARSIPARIS AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'CPNS Umum', 'khusus_disabilitas': True, 'penempatan': 'Nasional', 'min_gaji': 8.54, 'max_gaji': 10.53, 'jumlah_kebutuhan': 484, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 16}, page_content='Jabatan: ARSIPARIS AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Kejaksaan Agung\nPenempatan: Nasional\nCatatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).\nJenis Formasi: CPNS Umum\nKhusus Disabilitas: Ya\nPenghasilan (juta): 8.54 - 10.53\nJumlah Kebutuhan: 484\nKualifikasi Pendidikan: D4 PENGELOLAAN ARSIP DAN REKAMAN INFORMASI; D4 MANAJEMEN REKOD DAN ARSIP; D4 KEARSIPAN; D4 KEARSIPAN DIGITAL; S1 ILMU LINGKUNGAN; S1 ANTROPOLOGI; S1 ADMINISTRASI NEGARA; S1 KEHUTANAN; S1 EKONOMI; S1 PENDIDIKAN AGAMA ISLAM; S1 PENDIDIKAN KEAGAMAAN KATOLIK; S1 PENDIDIKAN KEAGAMAAN BUDDHA; S1 ILMU KELAUTAN; S1 PENDIDIKAN KEAGAMAAN HINDU; S1 PENDIDIKAN KEAGAMAAN KRISTEN; S1 SEJARAH; S1 ILMU SEJARAH; S1 PSIKOLOGI; S1 SOSIOLOGI; S1 ILMU PERPUSTAKAAN; S1 KEARSIPAN; S1 PENDIDIKAN ILMU PENGETAHUAN SOSIAL; S1 ILMU PERTANIAN; S1 HUBUNGAN MASYARAKAT\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'ARSIPARIS AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'CPNS Penyandang Disabilitas', 'khusus_disabilitas': True, 'penempatan': 'Nasional', 'min_gaji': 8.54, 'max_gaji': 10.53, 'jumlah_kebutuhan': 64, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 17}, page_content='Jabatan: ARSIPARIS AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Kejaksaan Agung\nPenempatan: Nasional\nCatatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).\nJenis Formasi: CPNS Penyandang Disabilitas\nKhusus Disabilitas: Ya\nPenghasilan (juta): 8.54 - 10.53\nJumlah Kebutuhan: 64\nKualifikasi Pendidikan: D4 PENGELOLAAN ARSIP DAN REKAMAN INFORMASI; D4 MANAJEMEN REKOD DAN ARSIP; D4 KEARSIPAN; D4 KEARSIPAN DIGITAL; S1 ILMU LINGKUNGAN; S1 ANTROPOLOGI; S1 ADMINISTRASI NEGARA; S1 KEHUTANAN; S1 EKONOMI; S1 PENDIDIKAN AGAMA ISLAM; S1 PENDIDIKAN KEAGAMAAN KATOLIK; S1 PENDIDIKAN KEAGAMAAN BUDDHA; S1 ILMU KELAUTAN; S1 PENDIDIKAN KEAGAMAAN HINDU; S1 PENDIDIKAN KEAGAMAAN KRISTEN; S1 SEJARAH; S1 ILMU SEJARAH; S1 PSIKOLOGI; S1 SOSIOLOGI; S1 ILMU PERPUSTAKAAN; S1 KEARSIPAN; S1 PENDIDIKAN ILMU PENGETAHUAN SOSIAL; S1 ILMU PERTANIAN; S1 HUBUNGAN MASYARAKAT\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'ARSIPARIS AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'CPNS Putra/putri Papua Dan Papua Barat', 'khusus_disabilitas': False, 'penempatan': 'Nasional', 'min_gaji': 8.54, 'max_gaji': 10.53, 'jumlah_kebutuhan': 17, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 18}, page_content='Jabatan: ARSIPARIS AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Kejaksaan Agung\nPenempatan: Nasional\nCatatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).\nJenis Formasi: CPNS Putra/putri Papua Dan Papua Barat\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 8.54 - 10.53\nJumlah Kebutuhan: 17\nKualifikasi Pendidikan: D4 PENGELOLAAN ARS
T; D4 TERAPI GIGI; D4 TEKNISI GIGI; D4 TEKNIK ELEKTROMEDIK; D4 TEKNOLOGI REKAYASA ELEKTROMEDIS; D4 TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI; D4 RADIODIAGNOSTIK DAN RADIOTERAPI; D4 TEKNOLOGI RADIOLOGI PENCITRAAN; D4 TEKNIK RADIOLOGI; D4 RADIOLOGI; D4 ORTOTIK DAN PROSTETIK; D4 PENGOBATAN TRADISIONAL; D4 PENGOBATAN TRADISIONAL TIONGKOK; D4 SISTEM MANAJEMEN INFORMASI KESEHATAN; D4 ANALIS KESEHATAN; D4 TEKNOLOGI LABORATORIUM MEDIS; D4 TEKNOLOGI LABORATORIUM MEDIK; PROFESI DOKTER; PROFESI DOKTER GIGI; PROFESI PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; PROFESI APOTEKER; PROFESI NERS; PROFESI BIDAN; PROFESI DIETISIEN; PROFESI FISIOTERAPIS\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'ADMINISTRATOR KESEHATAN AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'PPPK Tenaga Kesehatan Umum', 'khusus_disabilitas': False, 'penempatan': 'Surabaya', 'min_gaji': 10, 'max_gaji': 10.5, 'jumlah_kebutuhan': 7, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 22}, page_content='Jabatan: ADMINISTRATOR KESEHATAN AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Rumah Sakit Adhyaksa Jawa Timur\nPenempatan: Surabaya\nJenis Formasi: PPPK Tenaga Kesehatan Umum\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 10 - 10.5\nJumlah Kebutuhan: 7\nKualifikasi Pendidikan: S1 KEDOKTERAN; S1 KEDOKTERAN GIGI; S1 PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; S1 PSIKOLOGI YANG LULUS SEBELUM TANGGAL 4 OKTOBER 2017 DAN TELAH DIKUKUHKAN SEBAGAI PSIKOLOG KLINIS; S1 KEPERAWATAN; S1 KEBIDANAN; S1 FARMASI; S1 KESEHATAN LINGKUNGAN; S1 GIZI; S1 ILMU GIZI; S1 GIZI DAN DIETETIKA; S1 GIZI KESEHATAN; S1 KESEHATAN MASYARAKAT; S1 ILMU KESEHATAN MASYARAKAT; S1 EPIDEMIOLOGI; S1 KESEHATAN KERJA; S1 KESELAMATAN DAN KESEHATAN KERJA; S1 ADMINISTRASI RUMAH SAKIT; S1 FISIOTERAPI; S1 REKAM MEDIS DAN INFORMASI KESEHATAN; S1 PEMINATAN/JURUSAN/PROGRAM STUDI/KONSENTRASI TEKNOLOGI LABORATORIUM KESEHATAN/TEKNOLOGI LABORATORIUM MEDIK; D4 KEPERAWATAN; D4 KEBIDANAN; D4 BIDAN PENDIDIK; D4 GIZI; D4 GIZI DAN DIETETIKA; D4 GIZI KLINIS; D4 GIZI KLINIK; D4 KESEHATAN LINGKUNGAN; D4 SANITASI LINGK
GOBATAN TRADISIONAL; D4 PENGOBATAN TRADISIONAL TIONGKOK; D4 SISTEM MANAJEMEN INFORMASI KESEHATAN; D4 ANALIS KESEHATAN; D4 TEKNOLOGI LABORATORIUM MEDIS; D4 TEKNOLOGI LABORATORIUM MEDIK; PROFESI DOKTER; PROFESI DOKTER GIGI; PROFESI PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; PROFESI APOTEKER; PROFESI NERS; PROFESI BIDAN; PROFESI DIETISIEN; PROFESI FISIOTERAPIS\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'APOTEKER AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'PPPK Tenaga Kesehatan Khusus', 'khusus_disabilitas': False, 'penempatan': 'Banten', 'min_gaji': 10, 'max_gaji': 10.5, 'jumlah_kebutuhan': 3, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 26}, page_content='Jabatan: APOTEKER AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Rumah Sakit Adhyaksa Banten\nPenempatan: Banten\nJenis Formasi: PPPK Tenaga Kesehatan Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 10 - 10.5\nJumlah Kebutuhan: 3\nKualifikasi Pendidikan: S1 KEDOKTERAN; S1 KEDOKTERAN GIGI; S1 PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; S1 PSIKOLOGI YANG LULUS SEBELUM TANGGAL 4 OKTOBER 2017 DAN TELAH DIKUKUHKAN SEBAGAI PSIKOLOG KLINIS; S1 KEPERAWATAN; S1 KEBIDANAN; S1 FARMASI; S1 KESEHATAN LINGKUNGAN; S1 GIZI; S1 ILMU GIZI; S1 GIZI DAN DIETETIKA; S1 GIZI KESEHATAN; S1 KESEHATAN MASYARAKAT; S1 ILMU KESEHATAN MASYARAKAT; S1 EPIDEMIOLOGI; S1 KESEHATAN KERJA; S1 KESELAMATAN DAN KESEHATAN KERJA; S1 ADMINISTRASI RUMAH SAKIT; S1 FISIOTERAPI; S1 REKAM MEDIS DAN INFORMASI KESEHATAN; S1 PEMINATAN/JURUSAN/PROGRAM STUDI/KONSENTRASI TEKNOLOGI LABORATORIUM KESEHATAN/TEKNOLOGI LABORATORIUM MEDIK; D4 KEPERAWATAN; D4 KEBIDANAN; D4 BIDAN PENDIDIK; D4 GIZI; D4 GIZI DAN DIETETIKA; D4 GIZI KLINIS; D4 GIZI KLINIK; D4 KESEHATAN LINGKUNGAN; D4 SANITASI LINGKUNGAN; D4 EPIDEMIOLOGI; D4 KESEHATAN KERJA; D4 KESELAMATAN DAN KESEHATAN KERJA; D4 KESEHATAN DAN KESELAMATAN KERJA; D4 PROMOSI KESEHATAN; D4 FISIOTERAPI; D4 TERAPI WICARA DAN BAHASA; D4 OKUPASI TERAPI; D4 AKUPUNKTUR; D4 AKUPUNKTUR DAN PENGOBATAN HERBAL; D4 REKAM MEDIS DAN INFORMASI KESEHATAN; D4 REKAM MEDIS; D4 MANAJEMEN INFORMASI KESEHATAN; D4 KEPERAWATAN ANESTESIOLOGI; D4 KEPERAWATAN GIGI; D4 KESEHATAN GIGI; D4 TERAPI GIGI DAN MULUT; D4 TERAPI GIGI; D4 TEKNISI GIGI; D4 TEKNIK ELEKTROMEDIK; D4 TEKNOLOGI REKAYASA ELEKTROMEDIS; D4 TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI; D4 RADIODIAGNOSTIK DAN RADIOTERAPI; D4 TEKNOLOGI RADIOLOGI PENCITRAAN; D4 TEKNIK RADIOLOGI; D4 RADIOLOGI; D4 ORTOTIK DAN PROSTETIK; D4 PENGOBATAN TRADISIONAL; D4 PENGOBATAN TRADISIONAL TIONGKOK; D4 SISTEM MANAJEMEN INFORMASI KESEHATAN; D4 ANALIS KESEHATAN; D4 TEKNOLOGI LABORATORIUM MEDIS; D4 TEKNOLOGI LABORATORIUM MEDIK; PROFESI DOKTER; PROFESI DOKTER GIGI; PROFESI PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; PROFESI APOTEKER; PROFESI NERS; PROFESI BIDAN; PROFESI DIETISIEN; PROFESI FISIOTERAPIS\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'APOTEKER AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'PPPK Tenaga Kesehatan Umum', 'khusus_disabilitas': False, 'penempatan': None, 'min_gaji': 10, 'max_gaji': 10.5, 'jumlah_kebutuhan': 2, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 27}, page_content='Jabatan: APOTEKER AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Rumah Sakit Adhyaksa Jakarta\nPenempatan: Tidak disebutkan\nJenis Formasi: PPPK Tenaga Kesehatan Umum\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 10 - 10.5\nJumlah Kebutuhan: 2\nKualifikasi Pendidikan: S1 KEDOKTERAN; S1 KEDOKTERAN GIGI; S1 PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; S1 PSIKOLOGI YANG LULUS SEBELUM TANGGAL 4 OKTOBER 2017 DAN TELAH DIKUKUHKAN SEBAGAI PSIKOLOG KLINIS; S1 KEPERAWATAN; S1 KEBIDANAN; S1 FARMASI; S1 KESEHATAN LINGKUNGAN; S1 GIZI; S1 ILMU GIZI; S1 GIZI DAN DIETETIKA; S1 GIZI KESEHATAN; S1 KESEHATAN MASYARAKAT; S1 ILMU KESEHATAN MASYARAKAT; S1 EPIDEMIOLOGI; S1 KESEHATAN KERJA; S1 KESELAMATAN DAN KESEHATAN KERJA; S1 ADMINISTRASI RUMAH SAKIT; S1 FISIOTERAPI; S1 REKAM MEDIS DAN INFORMASI KESEHATAN; S1 PEMINATAN/JURUSAN/PROGRAM STUDI/KONSENTRASI TEKNOLOGI LABORATORIUM KESEHATAN/TEKNOLOGI LABORATORIUM MEDIK; D4 KEPERAWATAN; D4 KEBIDANAN; D4 BIDAN PENDIDIK; D4 GIZI; D4 GIZI DAN DIETETIKA; D4 GIZI KLINIS; D4 GIZI KLINIK; D4 KESEHATAN LINGKUNGAN; D4 SANITASI LINGKUNGAN; D4 EPIDEMIOLOGI; D4 KESEHATAN KERJA; D4 KESELAMATAN DAN KESEHATAN KERJA; D4 KESEHATAN DAN KESELAMATAN KERJA; D4 PROMOSI KESEHATAN; D4 FISIOTERAPI; D4 TERAPI WICARA DAN BAHASA; D4 OKUPASI TERAPI; D4 AKUPUNKTUR; D4 AKUPUNKTUR DAN PENGOBATAN HERBAL; D4 REKAM MEDIS DAN INFORMASI KESEHATAN; D4 REKAM MEDIS; D4 MANAJEMEN INFORMASI KESEHATAN; D4 KEPERAWATAN ANESTESIOLOGI; D4 KEPERAWATAN GIGI; D4 KESEHATAN GIGI; D4 TERAPI GIGI DAN MULUT; D4 TERAPI GIGI; D4 TEKNISI GIGI; D4 TEKNIK ELEKTROMEDIK; D4 TEKNOLOGI REKAYASA ELEKTROMEDIS; D4 TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI; D4 RADIODIAGNOSTIK DAN RADIOTERAPI; D4 TEKNOLOGI RADIOLOGI PENCITRAAN; D4 TEKNIK RADIOLOGI; D4 RADIOLOGI; D4 ORTOTIK DAN PROSTETIK; D4 PENGOBATAN TRADISIONAL; D4 PENGOBATAN TRADISIONAL TIONGKOK; D4 SISTEM MANAJEMEN INFORMASI KESEHATAN; D4 ANALIS KESEHATAN; D4 TEKNOLOGI LABORATORIUM MEDIS; D4 TEKNOLOGI LABORATORIUM MEDIK; PROFESI DOKTER; PROFESI DOKTER GIGI; PROFESI PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; PROFESI APOTEKER; PROFESI NERS; PROFESI BIDAN; PROFESI DIETISIEN; PROFESI FISIOTERAPIS\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'APOTEKER AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'PPPK Tenaga Kesehatan Khusus', 'khusus_disabilitas': False, 'penempatan': 'Surabaya', 'min_gaji': 10, 'max_gaji': 10.5, 'jumlah_kebutuhan': 2, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 28}, page_content='Jabatan: APOTEKER AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Rumah Sakit Adhyaksa Jawa Timur\nPenempatan: Surabaya\nJenis Formasi: PPPK Tenaga Kesehatan Khusus\nKhusus Disabilitas: Tidak\nPenghasilan (juta): 10 - 10.5\nJumlah Kebutuhan: 2\nKualifikasi Pendidikan: S1 KEDOKTERAN; S1 KEDOKTERAN GIGI; S1 PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; S1 PSIKOLOGI YANG LULUS SEBELUM TANGGAL 4 OKTOBER 2017 DAN TELAH DIKUKUHKAN SEBAGAI PSIKOLOG KLINIS; S1 KEPERAWATAN; S1 KEBIDANAN; S1 FARMASI; S1 KESEHATAN LINGKUNGAN; S1 GIZI; S1 ILMU GIZI; S1 GIZI DAN DIETETIKA; S1 GIZI KESEHATAN; S1 KESEHATAN MASYARAKAT; S1 ILMU KESEHATAN MASYARAKAT; S1 EPIDEMIOLOGI; S1 KESEHATAN KERJA; S1 KESELAMATAN DAN KESEHATAN KERJA; S1 ADMINISTRASI RUMAH SAKIT; S1 FISIOTERAPI; S1 REKAM MEDIS DAN INFORMASI KESEHATAN; S1 PEMINATAN/JURUSAN/PROGRAM STUDI/KONSENTRASI TEKNOLOGI LABORATORIUM KESEHATAN/TEKNOLOGI LABORATORIUM MEDIK; D4 KEPERAWATAN; D4 KEBIDANAN; D4 BIDAN PENDIDIK; D4 GIZI; D4 GIZI DAN DIETETIKA; D4 GIZI KLINIS; D4 GIZI KLINIK; D4 KESEHATAN LINGKUNGAN; D4 SANITASI LINGKUNGAN; D4 EPIDEMIOLOGI; D4 KESEHATAN KERJA; D4 KESELAMATAN DAN KESEHATAN KERJA; D4 KESEHATAN DAN KESELAMATAN KERJA; D4 PROMOSI KESEHATAN; D4 FISIOTERAPI; D4 TERAPI WICARA DAN BAHASA; D4 OKUPASI TERAPI; D4 AKUPUNKTUR; D4 AKUPUNKTUR DAN PENGOBATAN HERBAL; D4 REKAM MEDIS DAN INFORMASI KESEHATAN; D4 REKAM MEDIS; D4 MANAJEMEN INFORMASI KESEHATAN; D4 KEPERAWATAN ANESTESIOLOGI; D4 KEPERAWATAN GIGI; D4 KESEHATAN GIGI; D4 TERAPI GIGI DAN MULUT; D4 TERAPI GIGI; D4 TEKNISI GIGI; D4 TEKNIK ELEKTROMEDIK; D4 TEKNOLOGI REKAYASA ELEKTROMEDIS; D4 TEKNIK RADIODIAGNOSTIK DAN RADIOTERAPI; D4 RADIODIAGNOSTIK DAN RADIOTERAPI; D4 TEKNOLOGI RADIOLOGI PENCITRAAN; D4 TEKNIK RADIOLOGI; D4 RADIOLOGI; D4 ORTOTIK DAN PROSTETIK; D4 PENGOBATAN TRADISIONAL; D4 PENGOBATAN TRADISIONAL TIONGKOK; D4 SISTEM MANAJEMEN INFORMASI KESEHATAN; D4 ANALIS KESEHATAN; D4 TEKNOLOGI LABORATORIUM MEDIS; D4 TEKNOLOGI LABORATORIUM MEDIK; PROFESI DOKTER; PROFESI DOKTER GIGI; PROFESI PSIKOLOGI PEMINATAN PSIKOLOGI KLINIS; PROFESI APOTEKER; PROFESI NERS; PROFESI BIDAN; PROFESI DIETISIEN; PROFESI FISIOTERAPIS\nWebsite Instansi: https://biropeg.kejaksaan.go.id/'),
#  Document(metadata={'jabatan': 'APOTEKER AHLI PERTAMA', 'instansi': 'Kejaksaan Agung', 'jenis_formasi': 'PPPK Tenaga Kesehatan Khusus', 'khusus_disabilitas': False, 'penempatan': None, 'min_gaji': 10, 'max_gaji': 10.5, 'jumlah_kebutuhan': 1, 'sumber_file': '/Users/muhammadzuamaalamin/Documents/risetmandiir/helpsekfix/data/data.json', 'index': 29}, page_content='Jabatan: APOTEKER AHLI PERTAMA\nInstansi: Kejaksaan Agung\nUnit Kerja: Rumah Sakit Adhyaksa Jakarta\nPenempatan: Tidak disebutkan\nJenis Formasi: PPPK Tenaga Kesehatan Kh
## Embedding
# 3) Siapkan embedding (sekali saja)
embeddings = HuggingFaceEmbeddings(
    model_name="/Users/muhammadzuamaalamin/Documents/fintunellm/model/multilingual-e5-large-instruct",
    model_kwargs={"device": "cpu"}   # ganti "cuda" / "mps" bila tersedia dan ingin pakai GPU/MPS
)
# embeddings = HuggingFaceEmbeddings(model_name="/Users/muhammadzuamaalamin/Documents/fintunellm/model/bge-m3",
#                                    model_kwargs={"device": "cpu"})

# %%
# 4) Buat FAISS index dari CHUNKS (penting: gunakan chunks)
db = FAISS.from_documents(documents, embeddings)
db.save_local("faiss_index")
del db  # hapus dari memori

# nanti kalau butuh lagi
db = FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True)

# %%
# 5) Pencarian mirip/kemiripan
query = "s1 hukum"
# Jika tersedia, gunakan method yang mengembalikan score
try:
    results_with_score = db.similarity_search_with_score(query, k=3)
    for idx, (doc, score) in enumerate(results_with_score, 1):
        print(f"Result {idx} — score={score:.4f}\n{doc.page_content[:800]}\n")
except AttributeError:
    # fallback bila method with_score tidak ada
    results = db.similarity_search(query, k=3)
    for idx, doc in enumerate(results, 1):
        print(f"Result {idx}\n{doc.page_content[:800]}\n")
# Out:
# Result 1 — score=0.3227
# Jabatan: ARSIPARIS AHLI PERTAMA
# Instansi: Kejaksaan Agung
# Unit Kerja: Kejaksaan Agung
# Penempatan: Nasional
# Catatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).
# Jenis Formasi: CPNS Putra/putri Papua Dan Papua Barat
# Khusus Disabilitas: Tidak
# Penghasilan (juta): 8.54 - 10.53
# Jumlah Kebutuhan: 17
# Kualifikasi Pendidikan: D4 PENGELOLAAN ARSIP DAN REKAMAN INFORMASI; D4 MANAJEMEN REKOD DAN ARSIP; D4 KEARSIPAN; D4 KEARSIPAN DIGITAL; S1 ILMU LINGKUNGAN; S1 ANTROPOLOGI; S1 ADMINISTRASI NEGARA; S1 KEHUTANAN; S1 EKONOMI; S1 PENDIDIKAN AGAMA ISLAM; S1 PENDIDIKAN KEAGAMAAN KATOLIK; S1 PENDIDIKAN KEAGAMAAN BUDDHA; S1 ILMU KELAUTAN; S1 PENDIDIKAN KEAGAMAAN HINDU; S1 PENDIDIKAN KEAGAMAAN KRISTEN; S1 SEJARAH; S1 ILMU SEJARAH; S1
#
# Result 2 — score=0.3230
# Jabatan: ARSIPARIS AHLI PERTAMA
# Instansi: Kejaksaan Agung
# Unit Kerja: Kejaksaan Agung
# Penempatan: Nasional
# Catatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).
# Jenis Formasi: CPNS Penyandang Disabilitas
# Khusus Disabilitas: Ya
# Penghasilan (juta): 8.54 - 10.53
# Jumlah Kebutuhan: 64
# Kualifikasi Pendidikan: D4 PENGELOLAAN ARSIP DAN REKAMAN INFORMASI; D4 MANAJEMEN REKOD DAN ARSIP; D4 KEARSIPAN; D4 KEARSIPAN DIGITAL; S1 ILMU LINGKUNGAN; S1 ANTROPOLOGI; S1 ADMINISTRASI NEGARA; S1 KEHUTANAN; S1 EKONOMI; S1 PENDIDIKAN AGAMA ISLAM; S1 PENDIDIKAN KEAGAMAAN KATOLIK; S1 PENDIDIKAN KEAGAMAAN BUDDHA; S1 ILMU KELAUTAN; S1 PENDIDIKAN KEAGAMAAN HINDU; S1 PENDIDIKAN KEAGAMAAN KRISTEN; S1 SEJARAH; S1 ILMU SEJARAH; S1 PSIKOLOGI; S1
#
# Result 3 — score=0.3251
# Jabatan: ARSIPARIS AHLI PERTAMA
# Instansi: Kejaksaan Agung
# Unit Kerja: Kejaksaan Agung
# Penempatan: Nasional
# Catatan Penempatan: Lokasi mengikuti satuan kerja yang dipilih di SSCASN (Kejaksaan Agung, Kejati, atau Kejari di seluruh Indonesia).
# Jenis Formasi: CPNS Putra/putri Kalimantan
# Khusus Disabilitas: Ya
# Penghasilan (juta): 8.54 - 10.53
# Jumlah Kebutuhan: 4
# Kualifikasi Pendidikan: D4 PENGELOLAAN ARSIP DAN REKAMAN INFORMASI; D4 MANAJEMEN REKOD DAN ARSIP; D4 KEARSIPAN; D4 KEARSIPAN DIGITAL; S1 ILMU LINGKUNGAN; S1 ANTROPOLOGI; S1 ADMINISTRASI NEGARA; S1 KEHUTANAN; S1 EKONOMI; S1 PENDIDIKAN AGAMA ISLAM; S1 PENDIDIKAN KEAGAMAAN KATOLIK; S1 PENDIDIKAN KEAGAMAAN BUDDHA; S1 ILMU KELAUTAN; S1 PENDIDIKAN KEAGAMAAN HINDU; S1 PENDIDIKAN KEAGAMAAN KRISTEN; S1 SEJARAH; S1 ILMU SEJARAH; S1 PSIKOLOGI; S1

# %%
# Setup LLM dan memory
llm = ChatOllama(model="gemma3:4b")  # sedikit randomness boleh, tapi rendah
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# Buat retriever
retriever = db.as_retriever(search_kwargs={"k": 3})

# %%
from langchain.output_parsers import ResponseSchema, StructuredOutputParser
schemas = [
        ResponseSchema(
            name="jawaban",
            description="Jawaban lengkap, jelas, dan sesuai instruksi dalam bahasa Indonesia yang mudah dipahami."
        )
    ]
output_parser = StructuredOutputParser.from_response_schemas(schemas)
format_instructions = output_parser.get_format_instructions()

# %%
from langchain.prompts import ChatPromptTemplate
prompt_template = ChatPromptTemplate.from_template("""
Kamu adalah asisten resmi dari Badan Kepegawaian Negara (BKN) yang membantu masyarakat memahami informasi seputar Aparatur Sipil Negara (ASN), termasuk CPNS, PPPK, formasi, kualifikasi pendidikan, alur pendaftaran, dan regulasi terkait.

Instruksi:
1. Jawab PERTANYAAN PENGGUNA secara LENGKAP namun LANGSUNG KE INTI.
   - Jika tentang formasi: sebutkan jabatan, instansi, jumlah kebutuhan, kualifikasi, dan gaji (jika ada).
   - Jika tentang konsep (misal: “Apa itu CPNS?”): beri penjelasan sederhana dalam bahasa Indonesia.
2. “S-1 semua jurusan” berarti semua lulusan S-1 boleh mendaftar (berlaku juga untuk S-2/S-3).
3. Jika ada banyak formasi:
   - Tampilkan SEMUA yang relevan.
   - Setiap formasi di baris terpisah.
   - Urutkan dari jumlah kebutuhan terbanyak → sedikit, lalu penghasilan sebagai pembanding.
4. Gunakan HANYA informasi dalam KONTEKS. Jangan mengarang.
5. Jika konteks tidak cukup:  
   → Untuk topik ASN: "Maaf, saya tidak tahu jawaban pastinya berdasarkan dokumen yang tersedia."  
   → Di luar topik: "Maaf, saya tidak tahu. Saya hanya bisa menjawab pertanyaan seputar formasi CPNS, kualifikasi pendidikan, dan informasi rekrutmen ASN berdasarkan dokumen resmi."
6. Arahkan ke https://sscasn.bkn.go.id untuk info lebih lanjut.

Pertanyaan pengguna: {question}
Konteks tambahan dari dokumen:
{context}
{format_instructions}
""")

# %%
# Chain
chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    verbose=False,
    combine_docs_chain_kwargs={
        "prompt": prompt_template.partial(format_instructions=format_instructions)
    }
)

# %%
# Normalisasi query pengguna
query = "formasi yang penempatannya ada di banten formasi apa aja ?"
response = chain.invoke({"question": query})

# Parsing
try:
    if isinstance(response, dict) and "answer" in response:
        raw_answer = response["answer"]
    else:
        raw_answer = str(response)

    parsed = output_parser.parse(raw_answer)
    jawaban = parsed.get("jawaban", "Maaf, saya tidak dapat memberikan jawaban.")
except Exception as e:
    print("⚠️ Gagal parsing:", e)
    print("Raw output:", raw_answer)
    jawaban = "Maaf, terjadi kesalahan saat memproses jawaban."

print("\n==============================")
print("💬 Jawaban Asisten BKN:")
print(jawaban)
print("==============================\n")
# Out:
# ==============================
# 💬 Jawaban Asisten BKN:
# Berdasarkan data yang tersedia, saat ini tidak terdapat formasi CPNS dengan penempatan di Banten. Semua formasi CPNS yang terdaftar saat ini memiliki penempatan di Jakarta, yaitu:
#
# *   **PENELITI AHLI MUDA**
#     Instansi: Badan Riset dan Inovasi Nasional
#     Unit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA
#     Penempatan: Jakarta
#     Jenis Formasi: CPNS Penyandang Disabilitas
#     Khusus Disabilitas: Ya
#     Penghasilan (juta): 7 - 11
#     Jumlah Kebutuhan: 10
#     Kualifikasi Pendidikan: S3 semua jurusan
#
# *   **PENELITI AHLI MUDA**
#     Instansi: Badan Riset dan Inovasi Nasional
#     Unit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA
#     Penempatan: Jakarta
#     Jenis Formasi: CPNS Lulusan Terbaik
#     Khusus Disabilitas: Ya
#     Penghasilan (juta): 7 - 11
#     Jumlah Kebutuhan: 75
#     Kualifikasi Pendidikan: S3 semua jurusan
#
# *   **PENELITI AHLI MUDA**
#     Instansi: Badan Riset dan Inovasi Nasional
#     Unit Kerja: Badan Riset dan Inovasi Nasional | SEKRETARIAT UTAMA
#     Penempatan: Jakarta
#     Jenis Formasi: CPNS Diaspora
#     Khusus Disabilitas: Ya
#     Penghasilan (juta): 7 - 11
#     Jumlah Kebutuhan: 125
#     Kualifikasi Pendidikan: S3 semua jurusan
#
# Untuk informasi lebih lanjut mengenai formasi CPNS yang tersedia, silakan kunjungi https://sscasn.bkn.go.id
# ==============================
